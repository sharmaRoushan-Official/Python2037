# %% [markdown]
# ### List Assignment

# %%
#1. Create a list of 5 numbers and print it.


#2. Write a program to find the length of a list.


#3. Write a program to add an element to the end of a list.


#4. Write a program to insert an element at a specific position in a list.


#5. Write a program to remove an element from a list.


#6. Write a program to find the largest number in a list.


#7. Write a program to find the smallest number in a list.


#8. Write a program to sort a list in ascending order.


#9. Write a program to count how many times a specific element appears in a list.


#10. Write a program to reverse a list.

# %% [markdown]
# #1. Create a list of 5 numbers and print it.

# %%
numbers=[50,60,70,80,90]
print(numbers)
# Out:
# [50, 60, 70, 80, 90]

# %% [markdown]
# #2. Write a program to find the length of a list.

# %%
numbers=[50,60,70,80,90]
print(len(numbers))
# Out:
# 5

# %% [markdown]
# #3. Write a program to add an element to the end of a list.

# %%
numbers=[50,60,70,80,90]
numbers.append(100)
print(numbers)
# Out:
# [50, 60, 70, 80, 90, 100]

# %% [markdown]
# #4. Write a program to insert an element at a specific position in a list.

# %%
numbers=[50,60,80,90]
numbers.insert(2,70)
print(numbers)
# Out:
# [50, 60, 70, 80, 90]

# %% [markdown]
# #5. Write a program to remove an element from a list.

# %%
numbers=[50,60,70,80,90]
numbers.remove(70)
print(numbers)
# Out:
# [50, 60, 80, 90]

# %% [markdown]
# #6. Write a program to find the largest number in a list.

# %%
numbers=[50,60,70,80,90]
print(max(numbers))
# Out:
# 90

# %% [markdown]
# #7. Write a program to find the smallest number in a list.

# %%
numbers=[50,60,70,80,90]
print(min(numbers))
# Out:
# 50

# %% [markdown]
# #8. Write a program to sort a list in ascending order.

# %%
numbers=[90,50,80,60,80]
numbers.sort()
print(numbers)
# Out:
# [50, 60, 80, 80, 90]

# %% [markdown]
# #9. Write a program to count how many times a specific element appears in a list.

# %%
numbers=[90,50,50,50,70,80]
print(numbers.count(50))
# Out:
# 3

# %% [markdown]
# #10. Write a program to reverse a list.

# %%
numbers=[90,90,50,60,70]
numbers.reverse()
print(numbers)
# Out:
# [70, 60, 50, 90, 90]
