# %% [markdown]
# 1. Whatr is string in python

# %% [markdown]
# A string in python is a sequence of unicode character enclosed in qoutes.

# %% [markdown]
# 6. write python program to check wheather a number is divisible by 5 or not.

# %%
num= int(input("enter a number:"))
if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# enter a number: 6
# Not divisible by 5

# %% [markdown]
# 7. Write a python program to check if a number is even or odd.

# %%
number= int(input("Enter a number"))
if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number 2
# Even

# %% [markdown]
# 8. Write a python program to check a character is vowel or consonent.

# %%
ch = input("Enter a character:").lower()
if ch in "aeiou":
    print("vowel")
else:
    print("consonent")
# Out:
# Enter a character: v
# consonent

# %% [markdown]
# 9. Write a python program to check if a person is  child (<=12), teenager(13-19), or adult(>=20)

# %%
age = int(input("Enter the age:"))
if age <=12:
    print("child")
elif age <=19:
    print("teenger")
else:
    print("adult")
# Out:
# Enter the age: 19
# teenger

# %% [markdown]
# 10. write a python program to classify a grade.
#
# > A:90-100
# > B:80-89
# > C:70-79
# > D:60-69
# > F:Below go

# %%
marks= int(input())
if marks <= 90 and marks <= 100:
    print("A")
elif marks <= 80 and marks <= 89:
    print("B")
elif marks <= 70 and marks <= 79:
    print("C")
elif marks <= 60 and marks <= 69:
    print("D")
else:
    print("Below go")
# Out:
#  75
# A

# %% [markdown]
# 11. Write a python program to sum 1-10 number.

# %%
sum = int(input())
for j in range (1,11):
    sum = sum + j
    print("sum=",sum)
# Out:
#  1
# sum= 2
# sum= 4
# sum= 7
# sum= 11
# sum= 16
# sum= 22
# sum= 29
# sum= 37
# sum= 46
# sum= 56

# %% [markdown]
# 12. Write a python program to sum of even numbers from 1-10 and odd number.

# %%
for j in range(1,11):
    if j % 2 == 0:
        print(j,"Even")
    else:
        print(j,"Odd")
# Out:
# 1 Odd
# 2 Even
# 3 Odd
# 4 Even
# 5 Odd
# 6 Even
# 7 Odd
# 8 Even
# 9 Odd
# 10 Even

# %% [markdown]
# 2. Difference between find() and index()?

# %% [markdown]
#  find():element present by present and absent
# index(): element position

# %% [markdown]
# 3. Difference between split() and join()?

# %% [markdown]
# splip(): two element seprated by split()
# join(): two element join by join()

# %% [markdown]
# 4. Difference between strips,lstrip(),rstrip()?

# %% [markdown]
# strips(): space
# lstrips(): left side in strips
# rstrips(): right side in strips

# %% [markdown]
# 5. What is pop() and  pop(n) in list?

# %% [markdown]
# pop():remove the list elememt
# pop(n):remove the index.
