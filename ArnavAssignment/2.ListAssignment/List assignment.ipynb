# %%
l=[1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l=[1,2,3,4,5]
print(len(l))
# Out:
# 5

# %%
l=[1,2,3,4,5]
l.append(6)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l=[1,2,3,4,5]
l.insert(0,0)
print(l)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
l=[1,2,3,4,5]
l.remove(3)
print(l)
# Out:
# [1, 2, 4, 5]

# %%
l=[6,2,7,1,3,4,9]
l.sort()
print(l[6])
# Out:
# 9

# %%
l=[6,2,7,1,3,4,9]
l.sort()
print(l[0])
# Out:
# 1

# %%
l=[6,2,7,1,3,4,9]
l.sort()
print(l)
# Out:
# [1, 2, 3, 4, 6, 7, 9]

# %%
l=[1,3,2,5,3,5,6,7,3]
print(l.count(3))
# Out:
# 3

# %%
l=[6,2,7,1,3,4,9]
l.reverse()
print(l)
# Out:
# [9, 4, 3, 1, 7, 2, 6]
