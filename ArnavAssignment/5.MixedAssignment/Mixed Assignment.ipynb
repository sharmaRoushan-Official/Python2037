# %%
s=input("Enter a string:")
l=[]
for char in s:
    l.append(char)
print(l)
# Out:
# Enter a string: Arnav
# ['A', 'r', 'n', 'a', 'v']

# %%
l=["Arnav","Raj","Ram"]
t=tuple(l)
print(t)
# Out:
# ('Arnav', 'Raj', 'Ram')

# %%
l=[1,2,3,4,5,6]
l1=[2,4,6,8,10]
for i in l:
    if i in l1:
        print(i)
# Out:
# 2
# 4
# 6

# %%
t=("a","r","n","a","v")
"".join(t)
# Out:
# 'arnav'

# %%
s=input("Enter a string:")
l=s.split(" ")
print(len(l))
# Out:
# Enter a string: Hello world
# 2
