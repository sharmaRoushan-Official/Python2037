# %% [markdown]
# String Assginment

# %%
s=input("Enter a string:")
n=len(s)
print(n)
# Out:
# Enter a string: Hello world
# 11

# %%
s=input("Enter a string:")
print(s)
# Out:
# Enter a string: Hello world
# Hello world

# %%
s=input("Enter a string:")
UC=s.upper()
print(UC)
# Out:
# Enter a string: Hello world
# HELLO WORLD

# %%
s=input("Enter a string:")
LC=s.lower()
print(LC)
# Out:
# Enter a string: Hello World
# hello world

# %%
s=input("Enter a string:")
count=0
for ch in s:
        
    if ch=="a" or ch=="e" or ch=="i" or ch=="o" or ch=="u" or ch=="A" or ch=="E" or ch=="I" or ch=="O" or ch=="U":
                
        count+=1
print(count)
# Out:
# Enter a string: Hello world
# 3

# %%
s=input("Enter a string:")
print(s[::-1])
# Out:
# Enter a string: Hello world
# dlrow olleH

# %%
s=input("Enter a string:")
s1=s[::-1]
if s==s1:
    print("String is palindrome")
else:
    print("String is not palindrome")
# Out:
# Enter a string: asdfggfdsa
# String is palindrome

# %%
s=input("Enter a string:")
c1="l"
print(s.count(c1))
# Out:
# Enter a string: Hello world
# 3

# %%
s=input("Enter a string:")
s1="world"
s2="arnav"
print(s.replace(s1,s2))
# Out:
# Enter a string: Hello world
# Hello arnav

# %%
s=input("Enter a string:")
print(s.split(" "))
# Out:
# Enter a string: Welcome to pyhton
# ['Welcome', 'to', 'pyhton']
