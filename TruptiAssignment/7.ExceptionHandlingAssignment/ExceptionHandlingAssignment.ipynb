# %%
# ✅ *20 Python Try–Except–Else–Finally Practice Questions*

### *1. Basic Syntax*

# Write a Python program that takes a number from the user and prints its square. Use try and except to handle invalid (non-numeric) input.

---

### *2. Multiple Except Blocks*

# Write code that divides two numbers entered by the user. Handle:

* ValueError (invalid input)
* ZeroDivisionError (denominator = 0)

---

### *3. Using Else Block*

# Write a program where:

* try block attempts to open a file data.txt
* except handles FileNotFoundError
* else prints “File opened successfully”

---

### *4. Using Finally Block*

# Write a program that tries to read a file. Regardless of success or failure, print “Operation completed” using finally.

---

### *5. Catching Multiple Exceptions Together*

# Write code to convert a user’s input to an integer and catch *ValueError and TypeError* in a single except block.

---

### *6. Raising Exception*

# Write code that:

* Asks the user for age
* If age < 0, raise a ValueError
* Use try-except to handle the raised exception

---

### *7. Nested Try-Except*

# Simulate:

* Outer try: Convert input to integer
* Inner try: Divide 100 by that number
  Handle both errors separately.

---

### *8. Try–Except–Finally With File Closing*

# Open a file, read its contents, and ensure it closes in finally block even if an error occurs.

---

### *9. Try With Return Statement*

# Write a function using try-except-finally where the try returns a value but the finally also contains a return. Observe the output.

---

### *10. Custom Exception*

# Create a custom exception InvalidMarkError and raise it when marks > 100 or < 0. Handle it using try-except.

---

### *11. Else With No Exception*

# Write a program where:

* Try converts input to float
* Except handles invalid input
* Else prints “Conversion successful”

---

### *12. Handling KeyError*

# Write a program that accesses a dictionary key entered by the user and handles KeyError.

---

### *13. Handling IndexError*

# Ask the user for a list index and handle out-of-range cases.

---

### *14. Converting to Integer in a Loop*

# Loop until the user enters a valid integer. Use try-except to prevent program crash.

---

### *15. Try-Except Inside a Function*

# Create a function that calculates the square root of a number. Handle ValueError if input < 0.

---

### *16. Reading From a Possibly Corrupt File*

# Write a program that tries to read and convert each line of a file into an integer. Handle:

* FileNotFoundError
* ValueError (line cannot convert)

---

### *17. Finally for Cleanup*

# Simulate allocating a resource (print “Resource allocated”) and always free it in finally (“Resource released”) even if an exception occurs.

---

### *18. Multiple Excepts + Else + Finally*

# Solve this pattern:


try:
    # risky operation
except ValueError:
    # handle value error
except TypeError:
    # handle type error
else:
    # success
finally:
    # always executed


# Write any valid code to demonstrate this structure.

---

### *19. Re-Raising Exceptions*

# Catch a ValueError, print a message, and re-raise the exception.

---

### *20. Handling Unexpected Exceptions*

# Use a generic exception handler except Exception as e: to print error type and message.

# %% [markdown]
# ## *1. Basic Syntax*
#
# ### Write a Python program that takes a number from the user and prints its square. Use try and except to handle invalid (non-numeric) input.
#
# ---

# %%
try:
    number=int(input("enter a number:"))
    print("square=",number**2)
except valueError:
    print("invalid input please enter a number")
# Out:
# enter a number: 2
# square= 4

# %% [markdown]
# ## *2. Multiple Except Blocks*
#
# ### Write code that divides two numbers entered by the user. Handle:
#
# * ValueError (invalid input)
# * ZeroDivisionError (denominator = 0)

# %%
try:
    a=int(input("enter first number:"))
    b=int(input("enter second number:"))
    print("result=",a/b)
except valueError:
    print("invalid input")
except ZeroDivisionError:
    print("Zero Division Error")
# Out:
# enter first number: 50
# enter second number: 5
# result= 10.0

# %% [markdown]
# ## *3. Using Else Block*
#
# ### Write a program where:
#
# * try block attempts to open a file data.txt
# * except handles FileNotFoundError
# * else prints “File opened successfully”
#
# ---

# %%
try:
    file=open("data.txt","r")
except FileNotFoundError:
    print("file not found")
else:
    print("file opened successfully")
    file.close()
# Out:
# file not found

# %% [markdown]
# ## *4. Using Finally Block*
#
# ### Write a program that tries to read a file. Regardless of success or failure, print “Operation completed” using finally.

# %%
try:
    file=open("data.txt","r")
    print(file.read())
except FileNotFoundError:
    print("file not found")
finally:
    print("operation completed")
# Out:
# file not found
# operation completed

# %% [markdown]
# ## *5. Catching Multiple Exceptions Together*
#
# ###  Write code to convert a user’s input to an integer and catch *ValueError and TypeError* in a single except block.

# %%
try:
    num=int(input("enter a number:"))
    print(num)
except (valueError,TypeError):
    print("invalid input")
# Out:
# enter a number: 45
# 45

# %% [markdown]
# ## *6. Raising Exception*
#
# ### Write code that:
#
# * Asks the user for age
# * If age < 0, raise a ValueError
# * Use try-except to handle the raised exception

# %%
try:
    age=int(input("enter age:"))
    if age<0:
        raise valueError("Age cannot be negative")
    print("age=",age)
except valueError as e:
    print(e)
# Out:
# enter age: 20
# age= 20

# %% [markdown]
# ## *7. Nested Try-Except*
#
# ### Simulate:
#
# * Outer try: Convert input to integer
# * Inner try: Divide 100 by that number
#   Handle both errors separately.
#
# ---

# %%
try:
    num=int(input("enter number:"))
    try:
        print("result=",100/num)
    except ZeroDivisionError:
        print("cannot divide by zero")
except valueerror:
    print("invalid input")
# Out:
# enter number: 25
# result= 4.0

# %% [markdown]
# ## *8. Try–Except–Finally With File Closing*
#
# ### Open a file, read its contents, and ensure it closes in finally block even if an error occurs.

# %%
file=None
try:
    file=open("data.txt","r")
    print(file.read())
except FileNotFoundError:
    print("file not found")
finally:
    if file:
        file.close()
    print("file closed")
# Out:
# file not found
# file closed

# %% [markdown]
# ## *9. Try With Return Statement*
#
# ###  Write a function using try-except-finally where the try returns a value but the finally also contains a return. Observe the output.

# %%
def demo():
    try:
        print("Inside try block")
        return "return from try"
    except Exception:
        return "return from except"
    finally:
        print("inside finally block")
   # return ("return from finally")
result= demo()
print (result)
# Out:
# Inside try block
# inside finally block
# return from try

# %% [markdown]
# ## *10. Custom Exception*
#
# ### Create a custom exception InvalidMarkError and raise it when marks > 100 or < 0. Handle it using try-except.

# %%
class InvalidMarkError(Exception):
    pass
try:
    marks=int(input("enter marks:"))
    if marks<0 or marks>100:
        raise InvalidMarkError("invalid marks")
    print("marks=",marks)
except InvalidMarkError as e:
    print(e)
# Out:
# enter marks: 98
# marks= 98

# %% [markdown]
# ## *11. Else With No Exception*
#
# ### Write a program where:
#
# * Try converts input to float
# * Except handles invalid input
# * Else prints “Conversion successful”

# %%
try:
    num=int(input("enter number:"))
except ValueError:
    print("invalid input")
else:
    print("conversion successful")
# Out:
# enter number: 34
# conversion successful

# %% [markdown]
# ## *12. Handling KeyError*
#
# ### Write a program that accesses a dictionary key entered by the user and handles KeyError.

# %%
student={"name":"Trupti","age":20}
try:
    key=input("enter key:")
    print(student[key])
except KeyError:
    print("key not found")
# Out:
# enter key: name
# Trupti

# %% [markdown]
# ## *13. Handling IndexError*
#
# ### Ask the user for a list index and handle out-of-range cases.

# %%
list=[10,20,30]
try:
    index=int(input("enter index:"))
    print(list[index])
except IndexError:
    print("index out of range")
# Out:
# enter index: 1
# 20

# %% [markdown]
# ## *14. Converting to Integer in a Loop*
#
# ### Loop until the user enters a valid integer. Use try-except to prevent program crash.

# %%
while True:
    try:
        num=int(input("enter integer:"))
        print(num)
        break
    except ValueError:
        print("invalid input try again")
# Out:
# enter integer: 23
# 23

# %% [markdown]
# ## *15. Try-Except Inside a Function*
#
# ### Create a function that calculates the square root of a number. Handle ValueError if input < 0.

# %%
import math
def Squarenum():
    num=int(input("enter any number grater than 0:"))
    try:
        sqr=math.sqrt(num)
    except Exception as e:
        print("errro occured:",e)
    else:
        return f"square root of value is:(sqr)"
    finally:
        print(f"code excuted successfully")
Squarenum()
# Out:
# enter any number grater than 0: 1
# code excuted successfully
# 'square root of value is:(sqr)'

# %% [markdown]
# ### *16. Reading From a Possibly Corrupt File*
#
# ### Write a program that tries to read and convert each line of a file into an integer. Handle:
#
# * FileNotFoundError
# * ValueError (line cannot convert)

# %%
try:
    file=open("data.txt","r")
    for line in file:
        try:
            num=int(line.strip())
            print("integer:",num)
        except ValueError:
            print("cannot convert to integer:",line.strip())
    file.close()
except FileNotFoundError:
   print("file not found")
# Out:
# file not found

# %% [markdown]
# ### *17. Finally for Cleanup*
#
# ### Simulate allocating a resource (print “Resource allocated”) and always free it in finally (“Resource released”) even if an exception occurs.

# %%
try:
    print("resource allocated")
    x=10/0
except ZeroDivisionError:
    print("error occured")
finally:
    print("resource released")
# Out:
# resource allocated
# error occured
# resource released

# %% [markdown]
# ## *18. Multiple Excepts + Else + Finally*
#
# ### Solve this pattern:
#
#
# * try:
#     #### risky operation
# * except ValueError:
#     #### handle value error
# * except TypeError:
#     #### handle type error
# * else:
#     #### success
# * finally:
#     #### always executed
#
#
# ### Write any valid code to demonstrate this structure.

# %%
try:
    num=int(input("enter number:"))
    print(100/num)
except ValueError:
    print("value error")
except TypeError:
    print("Type Error")
else:
    print("success")
finally:
    print("always excuted")
# Out:
# enter number: 25
# 4.0
# success
# always excuted

# %% [markdown]
# ## *19. Re-Raising Exceptions*
#
# ### Catch a ValueError, print a message, and re-raise the exception.

# %%
try:
    num=int(input("enter number:"))
except ValueError:
    print("invalid input")
    raise
# Out:
# enter number: 23

# %% [markdown]
# ## *20. Handling Unexpected Exceptions*
#
# ### Use a generic exception handler except Exception as e: to print error type and message.

# %%
try:
    a=int(input("enter first number:"))
    b=int(input("enter second number:"))
    print(a/b)
except Exception as e:
    print("Error Type:",type(e)._name_)
    print("Error message:",e)
# Out:
# enter first number: 10
# enter second number: 5
# 2.0

# %%
# Beginner (1–10)

# 1. Write a program to handle a ZeroDivisionError.
# 2. Take two numbers from the user and handle invalid input using ValueError.
# 3. Open a file that does not exist and handle FileNotFoundError.
# 4. Access an invalid list index and handle IndexError.
# 5. Access a dictionary key that does not exist and handle KeyError.
# 6. Convert a string into an integer and handle invalid conversion.
# 7. Handle multiple exceptions (ValueError and ZeroDivisionError) in one program.
# 8. Use the else block in exception handling.
# 9. Use the finally block to display a message whether an exception occurs or not.
# 10. Write a program that asks for a number until the user enters a valid integer.


# Intermediate (11–20)

# 11. Read numbers from a file and handle exceptions if the file is missing.
# 12. Handle TypeError when adding an integer and a string.
# 13. Write a program to divide elements of two lists and handle division by zero.
# 14. Handle exceptions while taking a filename from the user.
# 15. Create a menu-driven calculator using exception handling.
# 16. Raise a custom exception if the user's age is less than 18.
# 17. Create a function that raises an exception if the password length is less than 8 characters.
# 18. Handle multiple exceptions in separate except blocks.
# 19. Write a nested try-except program.
# 20. Use try, except, else, and finally together in one program.



# Advanced (21–30)

# 21. Create a custom exception class called InvalidMarksError.
# 22. Raise an exception if marks are greater than 100 or less than 0.
# 23. Write a program that logs exceptions instead of printing them.
# 24. Create a bank withdrawal program that raises an exception for insufficient balance.
# 25. Handle exceptions while reading and writing files.
# 26. Create a function that validates email format and raises an exception if invalid.
# 27. Create a function to calculate the square root and raise an exception for negative numbers.
# 28. Use assert to check that a number is positive.
# 29. Create a student result program using custom exceptions for invalid marks and missing subjects.
# 30. Build a mini ATM program using exception handling (try, except, else, finally, raise, and custom exceptions).



# These questions cover:

try

except

else

finally

Multiple except blocks

Nested try

raise

assert

Custom exceptions

File handling exceptions

User input validation

Real-world exception handling scenarios

# %%
# Beginner (1–10)

# 1. Write a program to handle a ZeroDivisionError.
# 2. Take two numbers from the user and handle invalid input using ValueError.
# 3. Open a file that does not exist and handle FileNotFoundError.
# 4. Access an invalid list index and handle IndexError.
# 5. Access a dictionary key that does not exist and handle KeyError.
# 6. Convert a string into an integer and handle invalid conversion.
# 7. Handle multiple exceptions (ValueError and ZeroDivisionError) in one program.
# 8. Use the else block in exception handling.
# 9. Use the finally block to display a message whether an exception occurs or not.
# 10. Write a program that asks for a number until the user enters a valid integer.

# %% [markdown]
# ## 1. Write a program to handle a ZeroDivisionError.

# %%
try:
    a = 10
    b = 0
    print(a/b)
except ZeroDivisionError:
    print("Zero Division Error")
# Out:
# Zero Division Error

# %% [markdown]
# ## 2. Take two numbers from the user and handle invalid input using ValueError.

# %%
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print(a+b)
except ValueError:
    print("Invalid input")
# Out:
# Enter first number:  5
# Enter second number:  7.8
# Invalid input

# %% [markdown]
# ## 3. Open a file that does not exist and handle FileNotFoundError.

# %%
try:
    file = open("data.txt", "r")
    print(file.read())
    file.close()
except FileNotFoundError:
    print("File not found")
# Out:
# File not found

# %% [markdown]
# ## 4. Access an invalid list index and handle IndexError.

# %%
try:
    list = [10, 20, 30]
    print(list[4])
except IndexError:
    print("Invalid list index")
# Out:
# Invalid list index

# %% [markdown]
# ## 5. Access a dictionary key that does not exist and handle KeyError.

# %%
try:
    dictionary = {"name":"Trupti"}
    print(dictionary["age"])
except KeyError:
    print("Key does not exist")
# Out:
# Key does not exist

# %% [markdown]
# ## 6. Convert a string into an integer and handle invalid conversion.

# %%
try:
    n = int(input("Enter number: "))
    print(n)
except ValueError:
    print("Invalid conversion.")
# Out:
# Enter number:  trupti
# Invalid conversion.

# %% [markdown]
# ## 7. Handle multiple exceptions (ValueError and ZeroDivisionError) in one program.

# %%
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print(a/b)
except ValueError:
    print("Invalid input")
except ZeroDivisionError:
    print("Zero Division Error")
# Out:
# Enter first number:  12
# Enter second number:  0
# Zero Division Error

# %% [markdown]
# ## 8. Use the else block in exception handling.

# %%
try:
    n = int(input("Enter number: "))
except ValueError:
    print("Invalid input")
else:
    print(n)
# Out:
# Enter number:  23
# 23

# %% [markdown]
# ## 9. Use the finally block to display a message whether an exception occurs or not.

# %%
try:
    a = 10
    b = 2
    print(a/b)
except ZeroDivisionError:
    print("Error")
finally:
    print("successfully complete")
# Out:
# 5.0
# successfully complete

# %% [markdown]
# ## 10. Write a program that asks for a number until the user enters a valid integer.

# %%
while True:
    try:
        n = int(input("Enter an integer: "))
        print("Valid integer:",n)
        break
    except ValueError:
        print("Try again")
# Out:
# Enter an integer:  23
# Valid integer: 23

# %%
# Intermediate (11–20)

# 11. Read numbers from a file and handle exceptions if the file is missing.
# 12. Handle TypeError when adding an integer and a string.
# 13. Write a program to divide elements of two lists and handle division by zero.
# 14. Handle exceptions while taking a filename from the user.
# 15. Create a menu-driven calculator using exception handling.
# 16. Raise a custom exception if the user's age is less than 18.
# 17. Create a function that raises an exception if the password length is less than 8 characters.
# 18. Handle multiple exceptions in separate except blocks.
# 19. Write a nested try-except program.
# 20. Use try, except, else, and finally together in one program.

# %% [markdown]
# ## 11. Read numbers from a file and handle exceptions if the file is missing.

# %%
file=None
try:
    file=open(r"C:\Users\User\Desktop\NursaryRhymes.txt","r")
    content=file.read()
except FileNotFoundError:
    print("file is missing")
else:
    print(f"data is:\n{content}")
finally:
    if file:
        file.close()
        print("file successfully closed")
# Out:
# file is missing

# %% [markdown]
# ## 12. Handle TypeError when adding an integer and a string.

# %%
try:
    a = 10
    b = "20"
    print(a+b)
except TypeError:
    print("Cannot add int and string")
# Out:
# Cannot add int and string

# %% [markdown]
# ## 13. Write a program to divide elements of two lists and handle division by zero.

# %%
list1 = [20,5,24]
list2 = [10 ,0, 2]
for i in range(len(list1)):
    try:
        print(list1[i]/list2[i])
    except ZeroDivisionError:
        print("Division by zero.")
# Out:
# 5.0
# Division by zero.
# 6.0

# %% [markdown]
# ## 14. Handle exceptions while taking a filename from the user.

# %%
try:
    name = input("Enter filename: ")
    file = open(name, "r")
    print(file.read())
    file.close()
except FileNotFoundError:
    print("File not found.")
# Out:
# Enter filename:  trupti
# File not found.

# %% [markdown]
# ## 15. Create a menu-driven calculator using exception handling.

# %%
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("1.Add 2.Subtract 3.Multiply 4.Divide")
    ch = int(input("Choice: "))
    if ch == 1:
        print(a+b)
    elif ch == 2:
        print(a-b)
    elif ch == 3:
        print(a*b)
    elif ch == 4:
        print(a/b)
except ValueError:
    print("Invalid input")
except ZeroDivisionError:
    print("zero Division Error")
# Out:
# Enter first number:  10
# Enter second number:  0
# 1.Add 2.Subtract 3.Multiply 4.Divide
# Choice:  4.Divide
# Invalid input

# %% [markdown]
# ## 16. Raise a custom exception if the user's age is less than 18.

# %%
age = int(input("Enter age: "))
try:
    if age<18:
        raise Exception("Age must be 18 or above")
    print("Eligible ")
except Exception as e:
    print(e)
# Out:
# Enter age:  20
# Eligible

# %% [markdown]
# ## 17. Create a function that raises an exception if the password length is less than 8 characters.

# %%
def check_password(pwd):
    if len(pwd)< 8:
        raise Exception("Password too short.")
    print("Valid password")
try:
    p = input("Enter password: ")
    check_password(p)
except Exception as e:
    print(e)
# Out:
# Enter password:  1234567
# Password too short.

# %% [markdown]
# ## 18. Handle multiple exceptions in separate except blocks.

# %%
try:
    a = int(input("Enter number: "))
    print(10/a)
except ValueError:
    print("Invalid input")
except ZeroDivisionError:
    print("Zero Division Error")
# Out:
# Enter number:  20
# 0.5

# %% [markdown]
# ## 19. Write a nested try-except program.

# %%
try:
    try:
        a = int(input("Enter number: "))
        print(10/a)
    except ZeroDivisionError:
        print("Division by zero")
except ValueError:
    print("Invalid input")
# Out:
# Enter number:  5
# 2.0

# %% [markdown]
# ## 20. Use try, except, else, and finally together in one program.

# %%
try:
    n = int(input("Enter number: "))
except ValueError:
    print("Invalid input")
else:
    print(n*n)
finally:
    print("Program succesfully complete")
# Out:
# Enter number:  5
# 25
# Program succesfully complete

# %%
# Advanced (21–30)

# 21. Create a custom exception class called InvalidMarksError.
# 22. Raise an exception if marks are greater than 100 or less than 0.
# 23. Write a program that logs exceptions instead of printing them.
# 24. Create a bank withdrawal program that raises an exception for insufficient balance.
# 25. Handle exceptions while reading and writing files.
# 26. Create a function that validates email format and raises an exception if invalid.
# 27. Create a function to calculate the square root and raise an exception for negative numbers.
# 28. Use assert to check that a number is positive.
# 29. Create a student result program using custom exceptions for invalid marks and missing subjects.
# 30. Build a mini ATM program using exception handling (try, except, else, finally, raise, and custom exceptions).

# %% [markdown]
# ## 21. Create a custom exception class called InvalidMarksError.

# %%
class InvalidMarksError(Exception):
    pass

# %% [markdown]
# ## 22. Raise an exception if marks are greater than 100 or less than 0.

# %%
class InvalidMarksError(Exception):
    pass
try:
    marks = int(input("Enter marks: "))
    if marks < 0 or marks > 100:
        raise InvalidMarksError("Invalid marks")
    print("Marks accepted")
except InvalidMarksError as e:
    print(e)
# Out:
# Enter marks:  90
# Marks accepted

# %% [markdown]
# ## 23. Write a program that logs exceptions instead of printing them.

# %%
import logging
logging.basicConfig(filename="error.log", level=logging.ERROR)
try:
    print(10 / 0)
except Exception as e:
    logging.error(e)

# %% [markdown]
# ## 24. Create a bank withdrawal program that raises an exception for insufficient balance.

# %%
balance = 5000
try:
    amount = int(input("Enter amount: "))
    if amount > balance:
        raise Exception("Insufficient balance")
    balance -= amount
    print (balance)
except Exception as e:
    print(e)
# Out:
# Enter amount:  4500
# 500

# %% [markdown]
# ## 25. Handle exceptions while reading and writing files.

# %%
try:
    file = open("test.txt", "r")
    data = file.read()
    file.close()

    file = open("copy.txt", "w")
    file.write(data)
    file.close()
except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %% [markdown]
# ## 26. Create a function that validates email format and raises an exception if invalid.

# %%
def check_email(email):
    if "@" not in email or "." not in email:
        raise Exception("Invalid email.")
    print("Valid email.")

try:
    e = input("Enter email: ")
    check_email(e)
except Exception as ex:
    print(ex)
# Out:
# Enter email:  truptigaikwad576@gmail.com
# Valid email.

# %% [markdown]
# ## 27. Create a function to calculate the square root and raise an exception for negative numbers.

# %%
import math
try:
    n = int(input("Enter number: "))
    if n < 0:
        raise Exception("Negative number")
    print(math.sqrt(n))
except Exception as e:
    print(e)
# Out:
# Enter number:  4
# 2.0

# %% [markdown]
# ## 28. Use assert to check that a number is positive.

# %%
n = int(input("Enter number: "))
assert n > 0, "Number must be positive."
print("Valid number")
# Out:
# Enter number:  56
# Valid number

# %% [markdown]
# ## 29. Create a student result program using custom exceptions for invalid marks and missing subjects.

# %%
class InvalidMarksError(Exception):
    pass

try:
    marks = int(input("Enter marks: "))
    if marks < 0 or marks > 100:
        raise InvalidMarksError("Invalid marks")
    print( marks)
except InvalidMarksError as e:
    print(e)
# Out:
# Enter marks:  90
# 90

# %% [markdown]
# ## 30. Build a mini ATM program using exception handling (try, except, else, finally, raise, and custom exceptions).

# %%
class InsufficientBalance(Exception):
    pass

balance = 10000

try:
    amount = int(input("Enter withdrawal amount: "))
    if amount > balance:
        raise InsufficientBalance("Insufficient balance.")
except ValueError:
    print("Invalid input.")
except InsufficientBalance as e:
    print(e)
else:
    balance -= amount
    print("Withdrawal successful.")
    print("Balance:", balance)
finally:
    print("Thank you for using ATM.")
# Out:
# Enter withdrawal amount:  5000
# Withdrawal successful.
# Balance: 5000
# Thank you for using ATM.
